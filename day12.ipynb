# %%
import numpy as np

# %%
import pandas as pd

# %%
data = pd.read_csv(r"examples/ex5.csv")

# %%
data
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
data.to_csv("examples/out.csv")

# %%
# %pycat examples/out.csv
# Out:
# ,something,a,b,c,d,message
# 0,one,1,2,3.0,4,
# 1,two,5,6,,8,world
# 2,three,9,10,11.0,12,foo

# %%
import sys

# %%
data.to_csv(sys.stdout, sep = "|")
# Out:
# |something|a|b|c|d|message
# 0|one|1|2|3.0|4|
# 1|two|5|6||8|world
# 2|three|9|10|11.0|12|foo

# %%
data.to_csv(sys.stdout, na_rep = "NULL")
# Out:
# ,something,a,b,c,d,message
# 0,one,1,2,3.0,4,NULL
# 1,two,5,6,NULL,8,world
# 2,three,9,10,11.0,12,foo

# %%
data.to_csv(sys.stdout, index = False, header = False)
# Out:
# one,1,2,3.0,4,
# two,5,6,,8,world
# three,9,10,11.0,12,foo

# %%
data.to_csv(sys.stdout, index = False, columns = ["a", "b", "c"])
# Out:
# a,b,c
# 1,2,3.0
# 5,6,
# 9,10,11.0

# %%
# %pycat examples/ex7.csv
# Out:
# "a","b","c"
# "1","2","3"
# "1","2","3"

# %%
import csv

# %%
f = open("examples/ex7.csv")

# %%
reader = csv.reader(f)

# %%
for line in reader:
    print(line)
# Out:
# ['a', 'b', 'c']
# ['1', '2', '3']
# ['1', '2', '3']

# %%
 f.close()

# %%
with open("examples/ex7.csv") as f:
    lines = list(csv.reader(f))

# %%
header, values = lines[0], lines[1:]

# %%
data_dict = {h: v for h, v in zip(header, zip(*values))}

# %%
data_dict
# Out:
# {'a': ('1', '1'), 'b': ('2', '2'), 'c': ('3', '3')}

# %%
import json

# %%
obj = """
{"name":"wes",
"cities_lived": ["akron", "nashville", "new york", "san francisco"],
"pet": null,
"siblings":[{"name":"scott", "age": 34, "hobbies": ["guitars", "soccer"]},
            {"name" :"kattie", "age": 42, "hobbies": ["driving", "art"]}]
}
"""

# %%
result = json.loads(obj)

# %%
result
# Out:
# {'name': 'wes',
#  'cities_lived': ['akron', 'nashville', 'new york', 'san francisco'],
#  'pet': None,
#  'siblings': [{'name': 'scott', 'age': 34, 'hobbies': ['guitars', 'soccer']},
#   {'name': 'kattie', 'age': 42, 'hobbies': ['driving', 'art']}]}

# %%
asjson = json.dumps(result)

# %%
asjson
# Out:
# '{"name": "wes", "cities_lived": ["akron", "nashville", "new york", "san francisco"], "pet": null, "siblings": [{"name": "scott", "age": 34, "hobbies": ["guitars", "soccer"]}, {"name": "kattie", "age": 42, "hobbies": ["driving", "art"]}]}'

# %%
siblings = pd.DataFrame(result["siblings"], columns = ["name", "age"])

# %%
siblings
# Out:
#      name  age
# 0   scott   34
# 1  kattie   42

# %%
# %pycat examples/example.json
# Out:
# [{"a": 1, "b": 2, "c": 3},
#  {"a": 4, "b": 5, "c": 6},
#  {"a": 7, "b": 8, "c": 9}]

# %%
data = pd.read_json("examples/example.json")

# %%
data
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
data.to_json(sys.stdout)
# Out:
# {"a":{"0":1,"1":4,"2":7},"b":{"0":2,"1":5,"2":8},"c":{"0":3,"1":6,"2":9}}
