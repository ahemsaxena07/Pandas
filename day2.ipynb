# %%
import pandas as pd

# %%
data = {"state": ["ohio", "ohio", "ohio", "nevada", "nevada", "neveda"],
        "year": [2000, 2001, 2002, 2001, 2002, 2003],
        "pop": [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}

# %%
frame = pd.DataFrame(data)

# %%
frame
# Out:
#     state  year  pop
# 0    ohio  2000  1.5
# 1    ohio  2001  1.7
# 2    ohio  2002  3.6
# 3  nevada  2001  2.4
# 4  nevada  2002  2.9
# 5  neveda  2003  3.2

# %%
frame.head
# Out:
# <bound method NDFrame.head of     state  year  pop
# 0    ohio  2000  1.5
# 1    ohio  2001  1.7
# 2    ohio  2002  3.6
# 3  nevada  2001  2.4
# 4  nevada  2002  2.9
# 5  neveda  2003  3.2>

# %%
frame.tail
# Out:
# <bound method NDFrame.tail of     state  year  pop
# 0    ohio  2000  1.5
# 1    ohio  2001  1.7
# 2    ohio  2002  3.6
# 3  nevada  2001  2.4
# 4  nevada  2002  2.9
# 5  neveda  2003  3.2>

# %%
pd.DataFrame(data, columns = ["year", "state", "pop"])
# Out:
#    year   state  pop
# 0  2000    ohio  1.5
# 1  2001    ohio  1.7
# 2  2002    ohio  3.6
# 3  2001  nevada  2.4
# 4  2002  nevada  2.9
# 5  2003  neveda  3.2

# %%
frame2 = pd.DataFrame(data, columns = ["year", "state", "pop", "debt"])

# %%
frame2
# Out:
#    year   state  pop debt
# 0  2000    ohio  1.5  NaN
# 1  2001    ohio  1.7  NaN
# 2  2002    ohio  3.6  NaN
# 3  2001  nevada  2.4  NaN
# 4  2002  nevada  2.9  NaN
# 5  2003  neveda  3.2  NaN

# %%
frame2.columns
# Out:
# Index(['year', 'state', 'pop', 'debt'], dtype='str')

# %%
frame2["state"]
# Out:
# 0      ohio
# 1      ohio
# 2      ohio
# 3    nevada
# 4    nevada
# 5    neveda
# Name: state, dtype: str

# %%
frame2.year
# Out:
# 0    2000
# 1    2001
# 2    2002
# 3    2001
# 4    2002
# 5    2003
# Name: year, dtype: int64

# %%
frame2.loc[1]
# Out:
# year     2001
# state    ohio
# pop       1.7
# debt      NaN
# Name: 1, dtype: object

# %%
frame2.iloc[2]
# Out:
# year     2002
# state    ohio
# pop       3.6
# debt      NaN
# Name: 2, dtype: object

# %%
frame2["debt"] = 16.5

# %%
frame2
# Out:
#    year   state  pop  debt
# 0  2000    ohio  1.5  16.5
# 1  2001    ohio  1.7  16.5
# 2  2002    ohio  3.6  16.5
# 3  2001  nevada  2.4  16.5
# 4  2002  nevada  2.9  16.5
# 5  2003  neveda  3.2  16.5

# %%
import numpy as np

# %%
frame2["dept"] = np.arange(6.)

# %%
frame2
# Out:
#    year   state  pop  debt  dept
# 0  2000    ohio  1.5  16.5   0.0
# 1  2001    ohio  1.7  16.5   1.0
# 2  2002    ohio  3.6  16.5   2.0
# 3  2001  nevada  2.4  16.5   3.0
# 4  2002  nevada  2.9  16.5   4.0
# 5  2003  neveda  3.2  16.5   5.0

# %%
val = pd.Series([-1.2, -1.5, -1.7], index = ["two", "four", "five"])

# %%
frame2["debt"] = val

# %%
frame2
# Out:
#    year   state  pop  debt  dept
# 0  2000    ohio  1.5   NaN   0.0
# 1  2001    ohio  1.7   NaN   1.0
# 2  2002    ohio  3.6   NaN   2.0
# 3  2001  nevada  2.4   NaN   3.0
# 4  2002  nevada  2.9   NaN   4.0
# 5  2003  neveda  3.2   NaN   5.0

# %%
frame2["eastern"] = frame2["state"] == "ohio"

# %%
frame2
# Out:
#    year   state  pop  debt  dept  eastern
# 0  2000    ohio  1.5   NaN   0.0     True
# 1  2001    ohio  1.7   NaN   1.0     True
# 2  2002    ohio  3.6   NaN   2.0     True
# 3  2001  nevada  2.4   NaN   3.0    False
# 4  2002  nevada  2.9   NaN   4.0    False
# 5  2003  neveda  3.2   NaN   5.0    False

# %%
del frame2["eastern"]

# %%
frame2.columns
# Out:
# Index(['year', 'state', 'pop', 'debt', 'dept'], dtype='str')

# %%
del frame2["debt"]

# %%
frame2.columns
# Out:
# Index(['year', 'state', 'pop'], dtype='str')

# %%
frame2["dept"] = np.arange(6.)

# %%
frame2
# Out:
#    year   state  pop  dept
# 0  2000    ohio  1.5   0.0
# 1  2001    ohio  1.7   1.0
# 2  2002    ohio  3.6   2.0
# 3  2001  nevada  2.4   3.0
# 4  2002  nevada  2.9   4.0
# 5  2003  neveda  3.2   5.0

# %%
population = {"ohio": {2000: 1.5, 2001: 1.7, 2002: 3.6}, "nevada": {2001: 2.4, 2002: 2.9}}

# %%
frame3 = pd.DataFrame(population)

# %%
frame3
# Out:
#       ohio  nevada
# 2000   1.5     NaN
# 2001   1.7     2.4
# 2002   3.6     2.9

# %%
frame3.T
# Out:
#         2000  2001  2002
# ohio     1.5   1.7   3.6
# nevada   NaN   2.4   2.9

# %%
pd.DataFrame(population, index = [2001, 2002, 2003])
# Out:
#       ohio  nevada
# 2001   1.7     2.4
# 2002   3.6     2.9
# 2003   NaN     NaN

# %%
pdata = {"ohio": frame3["ohio"][:-1], "nevada": frame3["nevada"][:2]}

# %%
pd.DataFrame(pdata)
# Out:
#       ohio  nevada
# 2000   1.5     NaN
# 2001   1.7     2.4

# %%
frame3.index.name = "year"

# %%
frame3.columns.name = "state"

# %%
frame3
# Out:
# state  ohio  nevada
# year
# 2000    1.5     NaN
# 2001    1.7     2.4
# 2002    3.6     2.9

# %%
frame3.to_numpy()
# Out:
# array([[1.5, nan],
#        [1.7, 2.4],
#        [3.6, 2.9]])

# %%
frame2.to_numpy()
# Out:
# array([[2000, 'ohio', 1.5, 0.0],
#        [2001, 'ohio', 1.7, 1.0],
#        [2002, 'ohio', 3.6, 2.0],
#        [2001, 'nevada', 2.4, 3.0],
#        [2002, 'nevada', 2.9, 4.0],
#        [2003, 'neveda', 3.2, 5.0]], dtype=object)
