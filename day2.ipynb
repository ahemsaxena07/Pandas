# %%
import pandas as pd

# %%
data = {"state": ["ohio", "ohio", "ohio", "nevada", "nevada", "neveda"],
        "year": [2000, 2001, 2002, 2001, 2002, 2003],
        "pop": [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}

# %%
frame = pd.DataFrame(data)

# %%
frame
# Out:
#     state  year  pop
# 0    ohio  2000  1.5
# 1    ohio  2001  1.7
# 2    ohio  2002  3.6
# 3  nevada  2001  2.4
# 4  nevada  2002  2.9
# 5  neveda  2003  3.2

# %%
frame.head
# Out:
# <bound method NDFrame.head of     state  year  pop
# 0    ohio  2000  1.5
# 1    ohio  2001  1.7
# 2    ohio  2002  3.6
# 3  nevada  2001  2.4
# 4  nevada  2002  2.9
# 5  neveda  2003  3.2>

# %%
frame.tail
# Out:
# <bound method NDFrame.tail of     state  year  pop
# 0    ohio  2000  1.5
# 1    ohio  2001  1.7
# 2    ohio  2002  3.6
# 3  nevada  2001  2.4
# 4  nevada  2002  2.9
# 5  neveda  2003  3.2>

# %%
pd.DataFrame(data, columns = ["year", "state", "pop"])
# Out:
#    year   state  pop
# 0  2000    ohio  1.5
# 1  2001    ohio  1.7
# 2  2002    ohio  3.6
# 3  2001  nevada  2.4
# 4  2002  nevada  2.9
# 5  2003  neveda  3.2

# %%
frame2 = pd.DataFrame(data, columns = ["year", "state", "pop", "debt"])

# %%
frame2
# Out:
#    year   state  pop debt
# 0  2000    ohio  1.5  NaN
# 1  2001    ohio  1.7  NaN
# 2  2002    ohio  3.6  NaN
# 3  2001  nevada  2.4  NaN
# 4  2002  nevada  2.9  NaN
# 5  2003  neveda  3.2  NaN

# %%
frame
