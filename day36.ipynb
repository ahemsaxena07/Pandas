# %%
import numpy as np

# %%
import pandas as pd

# %%
from datetime import datetime

# %%
dates = [datetime(2011, 1, 2), datetime(2011, 1, 5), datetime(2011, 1, 7), datetime(2011, 1, 8), datetime(2011, 1, 10), datetime(2011, 1, 12)]

# %%
ts = pd.Series(np.random.standard_normal(6), index=dates)

# %%
ts
# Out:
# 2011-01-02   -1.592120
# 2011-01-05   -0.853883
# 2011-01-07   -0.782068
# 2011-01-08   -1.311446
# 2011-01-10   -0.253898
# 2011-01-12   -0.421221
# dtype: float64

# %%
 ts.index
# Out:
# DatetimeIndex(['2011-01-02', '2011-01-05', '2011-01-07', '2011-01-08',
#                '2011-01-10', '2011-01-12'],
#               dtype='datetime64[us]', freq=None)

# %%
ts + ts[::2]
# Out:
# 2011-01-02   -3.184239
# 2011-01-05         NaN
# 2011-01-07   -1.564136
# 2011-01-08         NaN
# 2011-01-10   -0.507797
# 2011-01-12         NaN
# dtype: float64

# %%
ts.index.dtype
# Out:
# dtype('<M8[us]')

# %%
stamp = ts.index[0]

# %%
stamp
# Out:
# Timestamp('2011-01-02 00:00:00')

# %%
stamp = ts.index[2]

# %%
ts[stamp]
# Out:
# np.float64(-0.7820679860206615)

# %%
ts["2011-01-10"]
# Out:
# np.float64(-0.2538983486232092)

# %%
longer_ts = pd.Series(np.random.standard_normal(1000), index=pd.date_range("2000-01-01", periods = 1000))

# %%
longer_ts
# Out:
# 2000-01-01    1.681966
# 2000-01-02    0.091932
# 2000-01-03   -1.393692
# 2000-01-04    1.006396
# 2000-01-05    0.503243
#                 ...
# 2002-09-22    0.356343
# 2002-09-23   -0.773404
# 2002-09-24   -2.151402
# 2002-09-25    1.453257
# 2002-09-26   -0.458170
# Freq: D, Length: 1000, dtype: float64

# %%
longer_ts["2001"]
# Out:
# 2001-01-01   -1.052679
# 2001-01-02    0.543140
# 2001-01-03    0.358444
# 2001-01-04   -1.396913
# 2001-01-05    0.241403
#                 ...
# 2001-12-27    0.177818
# 2001-12-28    1.573802
# 2001-12-29    0.954904
# 2001-12-30    0.696789
# 2001-12-31    0.858092
# Freq: D, Length: 365, dtype: float64

# %%
longer_ts["2001-05"]
# Out:
# 2001-05-01    1.387441
# 2001-05-02   -0.053265
# 2001-05-03   -0.622266
# 2001-05-04    0.039946
# 2001-05-05   -0.618330
# 2001-05-06   -1.233116
# 2001-05-07    1.388531
# 2001-05-08   -1.091216
# 2001-05-09    0.094630
# 2001-05-10   -1.957460
# 2001-05-11    1.192488
# 2001-05-12   -0.215684
# 2001-05-13    0.376608
# 2001-05-14   -1.393617
# 2001-05-15    1.455610
# 2001-05-16    1.341045
# 2001-05-17    1.014593
# 2001-05-18   -1.360467
# 2001-05-19    0.242015
# 2001-05-20    1.013987
# 2001-05-21    0.692318
# 2001-05-22   -0.436736
# 2001-05-23   -0.554688
# 2001-05-24    0.597723
# 2001-05-25   -0.556177
# 2001-05-26    0.767142
# 2001-05-27   -0.363615
# 2001-05-28    1.205956
# 2001-05-29   -1.798191
# 2001-05-30    0.313779
# 2001-05-31   -1.839238
# Freq: D, dtype: float64

# %%
ts[datetime(2011, 1, 7):]
# Out:
# 2011-01-07   -0.782068
# 2011-01-08   -1.311446
# 2011-01-10   -0.253898
# 2011-01-12   -0.421221
# dtype: float64

# %%
ts.truncate(after="2011-01-09")
# Out:
# 2011-01-02   -1.592120
# 2011-01-05   -0.853883
# 2011-01-07   -0.782068
# 2011-01-08   -1.311446
# dtype: float64

# %%
dates = pd.date_range("2001-01-01", periods = 100, freq = "W-WED")

# %%
long_df = pd.DataFrame(np.random.standard_normal((100, 4)), index=dates, columns=["Colorado", "Texas", "New York", "Ohio"])

# %%
long_df.loc["2001-05"]
# Out:
#             Colorado     Texas  New York      Ohio
# 2001-05-02  1.553955  0.240889 -0.002593 -0.244723
# 2001-05-09  0.894004  0.774683 -0.884221  0.591724
# 2001-05-16 -0.161149 -1.048249 -2.356682  0.075592
# 2001-05-23  0.903454 -0.228580 -2.179279 -0.756754
# 2001-05-30  0.278602  2.119080 -0.216693 -0.463102

# %%
dates = pd.DatetimeIndex(["2001-01-01", "2000-01-02", "2000-01-02", "2000-01-02", "2000-01-03"])

# %%
dup_ts = pd.Series(np.arange(5), index = dates)

# %%
dup_ts
# Out:
# 2001-01-01    0
# 2000-01-02    1
# 2000-01-02    2
# 2000-01-02    3
# 2000-01-03    4
# dtype: int64

# %%
dup_ts.index.is_unique
# Out:
# False

# %%
dup_ts["2000-01-03"]
# Out:
# np.int64(4)

# %%
grouped = dup_ts.groupby(level = 0)

# %%
grouped.mean()
# Out:
# 2000-01-02    2.0
# 2000-01-03    4.0
# 2001-01-01    0.0
# dtype: float64

# %%
grouped.count()
# Out:
# 2000-01-02    3
# 2000-01-03    1
# 2001-01-01    1
# dtype: int64
