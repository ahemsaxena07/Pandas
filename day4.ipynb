# %%
import numpy as np

# %%
import pandas as pd

# %%
obj2 = pd.Series(np.arange(5.), index = ["a", "b", "c", "d", "e"])

# %%
obj2
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
new_obj = obj2.drop("c")

# %%
new_obj
# Out:
# a    0.0
# b    1.0
# d    3.0
# e    4.0
# dtype: float64

# %%
obj2.drop(["c", "d"])
# Out:
# a    0.0
# b    1.0
# e    4.0
# dtype: float64

# %%
data = pd.DataFrame(np.arange(16).reshape((4,4)), index = ["ohio", "colorodo", "utah", "new york"], columns = ["one", "two", "three", "four"])

# %%
data
# Out:
#           one  two  three  four
# ohio        0    1      2     3
# colorodo    4    5      6     7
# utah        8    9     10    11
# new york   12   13     14    15

# %%
data.drop(index = ["colorodo", "ohio"])
# Out:
#           one  two  three  four
# utah        8    9     10    11
# new york   12   13     14    15

# %%
data.drop(columns = ["two"])
# Out:
#           one  three  four
# ohio        0      2     3
# colorodo    4      6     7
# utah        8     10    11
# new york   12     14    15

# %%
data.drop("two", axis = 1)
# Out:
#           one  three  four
# ohio        0      2     3
# colorodo    4      6     7
# utah        8     10    11
# new york   12     14    15

# %%
data.drop(["two","four"], axis = "columns")
# Out:
#           one  three
# ohio        0      2
# colorodo    4      6
# utah        8     10
# new york   12     14

# %%
obj = pd.Series(np.arange(4.), index = ["a", "b", "c", "d"])

# %%
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# dtype: float64

# %%
obj["b"]
# Out:
# np.float64(1.0)

# %%
obj.iloc[1]
# Out:
# np.float64(1.0)

# %%
obj[["b", "a", "d"]]
# Out:
# b    1.0
# a    0.0
# d    3.0
# dtype: float64

# %%
obj.iloc[[1,3]]
# Out:
# b    1.0
# d    3.0
# dtype: float64

# %%
obj[obj<2]
# Out:
# a    0.0
# b    1.0
# dtype: float64

# %%
obj.loc[["b", "a", "d"]]
# Out:
# b    1.0
# a    0.0
# d    3.0
# dtype: float64

# %%
obj1 = pd.Series([1,2,3], index = [2,0,1])

# %%
obj2 = pd.Series([1,2,3], index = ["a","b","c"])

# %%
obj1
# Out:
# 2    1
# 0    2
# 1    3
# dtype: int64

# %%
obj2
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
obj1.iloc[[0,1,2]]
# Out:
# 2    1
# 0    2
# 1    3
# dtype: int64

# %%
obj2.iloc[[0,1]]
# Out:
# a    1
# b    2
# dtype: int64

# %%
obj2.loc["b":"c"]
# Out:
# b    2
# c    3
# dtype: int64

# %%
obj2.loc["b":"c"] = 5

# %%
obj2
# Out:
# a    1
# b    5
# c    5
# dtype: int64

# %%
data = pd.DataFrame(np.arange(16).reshape((4,4)), index = ["ohio", "colorado", "utah", "new york"], columns = ["one", "two", "three", "four"])

# %%
data
# Out:
#           one  two  three  four
# ohio        0    1      2     3
# colorado    4    5      6     7
# utah        8    9     10    11
# new york   12   13     14    15

# %%
data["two"]
# Out:
# ohio         1
# colorado     5
# utah         9
# new york    13
# Name: two, dtype: int64

# %%
data[["three", "one"]]
# Out:
#           three  one
# ohio          2    0
# colorado      6    4
# utah         10    8
# new york     14   12

# %%
data[:2]
# Out:
#           one  two  three  four
# ohio        0    1      2     3
# colorado    4    5      6     7

# %%
data[data["three"]>5]
# Out:
#           one  two  three  four
# colorado    4    5      6     7
# utah        8    9     10    11
# new york   12   13     14    15

# %%
data < 5
# Out:
#             one    two  three   four
# ohio       True   True   True   True
# colorado   True  False  False  False
# utah      False  False  False  False
# new york  False  False  False  False

# %%
data[data<5] = 0

# %%
data
# Out:
#           one  two  three  four
# ohio        0    0      0     0
# colorado    0    5      6     7
# utah        8    9     10    11
# new york   12   13     14    15

# %%
data
# Out:
#           one  two  three  four
# ohio        0    0      0     0
# colorado    0    5      6     7
# utah        8    9     10    11
# new york   12   13     14    15

# %%
data.loc["colorado"]
# Out:
# one      0
# two      5
# three    6
# four     7
# Name: colorado, dtype: int64

# %%
data.loc[["colorado", "new york"]]
# Out:
#           one  two  three  four
# colorado    0    5      6     7
# new york   12   13     14    15

# %%
data.loc["colorado", ["two","three"]]
# Out:
# two      5
# three    6
# Name: colorado, dtype: int64

# %%
data.iloc[2]
# Out:
# one       8
# two       9
# three    10
# four     11
# Name: utah, dtype: int64

# %%
data.iloc[[2,1]]
# Out:
#           one  two  three  four
# utah        8    9     10    11
# colorado    0    5      6     7

# %%
data.iloc[2, [3,0,1]]
# Out:
# four    11
# one      8
# two      9
# Name: utah, dtype: int64

# %%
data.iloc[[1,2], [3,0,1]]
# Out:
#           four  one  two
# colorado     7    0    5
# utah        11    8    9

# %%
data.loc[:"utah", "two"]
# Out:
# ohio        0
# colorado    5
# utah        9
# Name: two, dtype: int64

# %%
data.iloc[:,:3][data.three > 5]
# Out:
#           one  two  three
# colorado    0    5      6
# utah        8    9     10
# new york   12   13     14

# %%
data.loc[data.three >= 2]
# Out:
#           one  two  three  four
# colorado    0    5      6     7
# utah        8    9     10    11
# new york   12   13     14    15
