# %%
import numpy as np

# %%
import pandas as pd

# %%
data = pd.Series(np.random.uniform(size = 9), index = [["a", "a", "a", "b", "b", "c", "c", "d", "d"], [1,2,3,1,3,1,2,2,3]])

# %%
data
# Out:
# a  1    0.005046
#    2    0.536333
#    3    0.462940
# b  1    0.686331
#    3    0.564619
# c  1    0.815660
#    2    0.847416
# d  2    0.600784
#    3    0.458397
# dtype: float64

# %%
data.index
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('a', 3),
#             ('b', 1),
#             ('b', 3),
#             ('c', 1),
#             ('c', 2),
#             ('d', 2),
#             ('d', 3)],
#            )

# %%
data["b"]
# Out:
# 1    0.686331
# 3    0.564619
# dtype: float64

# %%
data["b":"c"]
# Out:
# b  1    0.686331
#    3    0.564619
# c  1    0.815660
#    2    0.847416
# dtype: float64

# %%
data.loc[["b", "d"]]
# Out:
# b  1    0.686331
#    3    0.564619
# d  2    0.600784
#    3    0.458397
# dtype: float64

# %%
data.loc[:,2]
# Out:
# a    0.536333
# c    0.847416
# d    0.600784
# dtype: float64

# %%
data.unstack()
# Out:
#           1         2         3
# a  0.005046  0.536333  0.462940
# b  0.686331       NaN  0.564619
# c  0.815660  0.847416       NaN
# d       NaN  0.600784  0.458397

# %%
data.unstack().stack()
# Out:
# a  1    0.005046
#    2    0.536333
#    3    0.462940
# b  1    0.686331
#    2         NaN
#    3    0.564619
# c  1    0.815660
#    2    0.847416
#    3         NaN
# d  1         NaN
#    2    0.600784
#    3    0.458397
# dtype: float64

# %%
frame = pd.DataFrame(np.arange(12).reshape((4,3)), index = [["a", "a", "b", "b"], [1,2,1,2]], columns = [["ohio", "ohio", "colorado"],["green", "red", "green"]])

# %%
frame
# Out:
#      ohio     colorado
#     green red    green
# a 1     0   1        2
#   2     3   4        5
# b 1     6   7        8
#   2     9  10       11

# %%
frame.index.names = ["key1", "key2"]

# %%
frame.columns.names = ["state", "color"]

# %%
frame
# Out:
# state      ohio     colorado
# color     green red    green
# key1 key2
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %%
frame.index.nlevels
# Out:
# 2

# %%
frame["ohio"]
# Out:
# color      green  red
# key1 key2
# a    1         0    1
#      2         3    4
# b    1         6    7
#      2         9   10

# %%
pd.MultiIndex.from_arrays([["ohio", "ohio", "colorado"], ["green", "red", "green"]], names = ["state", "color"])
# Out:
# MultiIndex([(    'ohio', 'green'),
#             (    'ohio',   'red'),
#             ('colorado', 'green')],
#            names=['state', 'color'])

# %%
frame.swaplevel("key1", "key2")
# Out:
# state      ohio     colorado
# color     green red    green
# key2 key1
# 1    a        0   1        2
# 2    a        3   4        5
# 1    b        6   7        8
# 2    b        9  10       11

# %%
frame.sort_index(level = 1)
# Out:
# state      ohio     colorado
# color     green red    green
# key1 key2
# a    1        0   1        2
# b    1        6   7        8
# a    2        3   4        5
# b    2        9  10       11

# %%
frame.swaplevel(0,1).sort_index(level=0)
# Out:
# state      ohio     colorado
# color     green red    green
# key2 key1
# 1    a        0   1        2
#      b        6   7        8
# 2    a        3   4        5
#      b        9  10       11

# %%
frame.groupby(level = "key2").sum()
# Out:
# state  ohio     colorado
# color green red    green
# key2
# 1         6   8       10
# 2        12  14       16

# %%
frame.T.groupby(level="color").sum().T
# Out:
# color      green  red
# key1 key2
# a    1         2    1
#      2         8    4
# b    1        14    7
#      2        20   10

# %%
frame = pd.DataFrame({"a": range(7), "b": range(7, 0, -1), "c":["one", "one", "one", "two", "two", "two","two"], "d":[0,1,2,0,1,2,3]})

# %%
frame
# Out:
#    a  b    c  d
# 0  0  7  one  0
# 1  1  6  one  1
# 2  2  5  one  2
# 3  3  4  two  0
# 4  4  3  two  1
# 5  5  2  two  2
# 6  6  1  two  3

# %%
frame2 = frame.set_index(["c", "d"])

# %%
frame2
# Out:
#        a  b
# c   d
# one 0  0  7
#     1  1  6
#     2  2  5
# two 0  3  4
#     1  4  3
#     2  5  2
#     3  6  1

# %%
frame.set_index(["c", "d"], drop=False)
# Out:
#        a  b    c  d
# c   d
# one 0  0  7  one  0
#     1  1  6  one  1
#     2  2  5  one  2
# two 0  3  4  two  0
#     1  4  3  two  1
#     2  5  2  two  2
#     3  6  1  two  3

# %%
frame2.reset_index()
# Out:
#      c  d  a  b
# 0  one  0  0  7
# 1  one  1  1  6
# 2  one  2  2  5
# 3  two  0  3  4
# 4  two  1  4  3
# 5  two  2  5  2
# 6  two  3  6  1
