# %%
import numpy as np

# %%
import pandas as pd

# %%
float_data = pd.Series([1.2, -3.5, np.nan, 0])

# %%
float_data
# Out:
# 0    1.2
# 1   -3.5
# 2    NaN
# 3    0.0
# dtype: float64

# %%
float_data.isna()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
string_data = pd.Series(["aardvark", np.nan, None, "avacado"])

# %%
string_data
# Out:
# 0    aardvark
# 1         NaN
# 2         NaN
# 3     avacado
# dtype: str

# %%
float_data = pd.Series([1,2, None], dtype = "float64")

# %%
float_data
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
float_data.isna()
# Out:
# 0    False
# 1    False
# 2     True
# dtype: bool

# %%
data = pd.Series([1, np.nan, 3.5, np.nan, 7])

# %%
data.dropna()
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data[data.notna()]
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data = pd.DataFrame([[1., 6.5, 3.], [1., np.nan, np.nan], [np.nan, np.nan, np.nan], [np.nan, 6.5, 3.]])

# %%
data
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
data.dropna()
# Out:
#      0    1    2
# 0  1.0  6.5  3.0

# %%
data.dropna(how = "all")
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 3  NaN  6.5  3.0

# %%
data[4] = np.nan

# %%
data
# Out:
#      0    1    2   4
# 0  1.0  6.5  3.0 NaN
# 1  1.0  NaN  NaN NaN
# 2  NaN  NaN  NaN NaN
# 3  NaN  6.5  3.0 NaN

# %%
data.dropna(axis = "columns", how="all")
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
df = pd.DataFrame(np.random.standard_normal((7,3)))

# %%
df.iloc[:4,1] = np.nan

# %%
df.iloc[:2, 2] = np.nan

# %%
df
# Out:
#           0         1         2
# 0 -0.483329       NaN       NaN
# 1  0.890992       NaN       NaN
# 2  1.836544       NaN -0.282342
# 3  0.806580       NaN -0.274558
# 4  0.658088  0.025982  0.648196
# 5 -1.301300  0.341345  1.870639
# 6 -0.087139 -0.552713  0.097770

# %%
df.dropna()
# Out:
#           0         1         2
# 4  0.658088  0.025982  0.648196
# 5 -1.301300  0.341345  1.870639
# 6 -0.087139 -0.552713  0.097770

# %%
df.dropna(thresh = 2)
# Out:
#           0         1         2
# 2  1.836544       NaN -0.282342
# 3  0.806580       NaN -0.274558
# 4  0.658088  0.025982  0.648196
# 5 -1.301300  0.341345  1.870639
# 6 -0.087139 -0.552713  0.097770

# %%
df.fillna(0)
# Out:
#           0         1         2
# 0 -0.483329  0.000000  0.000000
# 1  0.890992  0.000000  0.000000
# 2  1.836544  0.000000 -0.282342
# 3  0.806580  0.000000 -0.274558
# 4  0.658088  0.025982  0.648196
# 5 -1.301300  0.341345  1.870639
# 6 -0.087139 -0.552713  0.097770

# %%
data = pd.Series([1., np.nan, 3.5, np.nan, 7.])

# %%
data.fillna(data.mean())
# Out:
# 0    1.000000
# 1    3.833333
# 2    3.500000
# 3    3.833333
# 4    7.000000
# dtype: float64

# %%
data = pd.DataFrame({"k1": ["one", "two"] * 3 + ["two"], "k2": [1,1,2,3,4,4,4]})

# %%
data
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   4
# 5  two   4
# 6  two   5

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
data.drop_duplicates()
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   4
# 5  two   4

# %%
data["v1"] = range(7)

# %%
data
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  two   1   1
# 2  one   2   2
# 3  two   3   3
# 4  one   4   4
# 5  two   4   5
# 6  two   4   6

# %%
data.drop_duplicates(subset = ["k1"])
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  two   1   1

# %%
data = pd.Series([1., -999., 2., -999., -1000., 3.])

# %%
data
# Out:
# 0       1.0
# 1    -999.0
# 2       2.0
# 3    -999.0
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data.replace(-999, np.nan)
# Out:
# 0       1.0
# 1       NaN
# 2       2.0
# 3       NaN
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data.replace([-999, -1000], [np.nan, 0])
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    0.0
# 5    3.0
# dtype: float64
