# %%
import numpy as np

# %%
import pandas as pd

# %%
import pytz

# %%
pytz.common_timezones[-5:]
# Out:
# ['US/Eastern', 'US/Hawaii', 'US/Mountain', 'US/Pacific', 'UTC']

# %%
tz = pytz.timezone("America/New_York")

# %%
tz
# Out:
# <DstTzInfo 'America/New_York' LMT-1 day, 19:04:00 STD>

# %%
dates = pd.date_range("2012-03-09 09:30", periods=6)

# %%
ts = pd.Series(np.random.standard_normal(len(dates)), index=dates)

# %%
ts
# Out:
# 2012-03-09 09:30:00    0.105947
# 2012-03-10 09:30:00    0.571502
# 2012-03-11 09:30:00    0.236482
# 2012-03-12 09:30:00   -0.749915
# 2012-03-13 09:30:00   -0.432236
# 2012-03-14 09:30:00   -2.384207
# Freq: D, dtype: float64

# %%
print(ts.index.tz)
# Out:
# None

# %%
pd.date_range("2012-03-09 09:30", periods = 10, tz = "UTC")
# Out:
# DatetimeIndex(['2012-03-09 09:30:00+00:00', '2012-03-10 09:30:00+00:00',
#                '2012-03-11 09:30:00+00:00', '2012-03-12 09:30:00+00:00',
#                '2012-03-13 09:30:00+00:00', '2012-03-14 09:30:00+00:00',
#                '2012-03-15 09:30:00+00:00', '2012-03-16 09:30:00+00:00',
#                '2012-03-17 09:30:00+00:00', '2012-03-18 09:30:00+00:00'],
#               dtype='datetime64[us, UTC]', freq='D')

# %%
ts
# Out:
# 2012-03-09 09:30:00    0.105947
# 2012-03-10 09:30:00    0.571502
# 2012-03-11 09:30:00    0.236482
# 2012-03-12 09:30:00   -0.749915
# 2012-03-13 09:30:00   -0.432236
# 2012-03-14 09:30:00   -2.384207
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC")

# %%
ts_utc
# Out:
# 2012-03-09 09:30:00+00:00    0.105947
# 2012-03-10 09:30:00+00:00    0.571502
# 2012-03-11 09:30:00+00:00    0.236482
# 2012-03-12 09:30:00+00:00   -0.749915
# 2012-03-13 09:30:00+00:00   -0.432236
# 2012-03-14 09:30:00+00:00   -2.384207
# Freq: D, dtype: float64

# %%
ts_utc.index
# Out:
# DatetimeIndex(['2012-03-09 09:30:00+00:00', '2012-03-10 09:30:00+00:00',
#                '2012-03-11 09:30:00+00:00', '2012-03-12 09:30:00+00:00',
#                '2012-03-13 09:30:00+00:00', '2012-03-14 09:30:00+00:00'],
#               dtype='datetime64[us, UTC]', freq='D')

# %%
ts_utc.tz_convert("America/New_York")
# Out:
# 2012-03-09 04:30:00-05:00    0.105947
# 2012-03-10 04:30:00-05:00    0.571502
# 2012-03-11 05:30:00-04:00    0.236482
# 2012-03-12 05:30:00-04:00   -0.749915
# 2012-03-13 05:30:00-04:00   -0.432236
# 2012-03-14 05:30:00-04:00   -2.384207
# dtype: float64

# %%
ts_eastern = ts.tz_localize("America/New_York")

# %%
ts_eastern.tz_convert("Europe/Berlin")
# Out:
# 2012-03-09 15:30:00+01:00    0.105947
# 2012-03-10 15:30:00+01:00    0.571502
# 2012-03-11 14:30:00+01:00    0.236482
# 2012-03-12 14:30:00+01:00   -0.749915
# 2012-03-13 14:30:00+01:00   -0.432236
# 2012-03-14 14:30:00+01:00   -2.384207
# dtype: float64

# %%
stamp = pd.Timestamp("2011-03-12 04:00")

# %%
stamp_utc = stamp.tz_localize("utc")

# %%
stamp_utc.tz_convert("America/New_York")
# Out:
# Timestamp('2011-03-11 23:00:00-0500', tz='America/New_York')

# %%
stamp_moscow = pd.Timestamp("2011-03-12 04:00", tz = "Europe/Moscow")

# %%
stamp_moscow
# Out:
# Timestamp('2011-03-12 04:00:00+0300', tz='Europe/Moscow')

# %%
stamp_utc.value
# Out:
# 1299902400000000000

# %%
stamp_utc.tz_convert("America/New_York").value
# Out:
# 1299902400000000000

# %%
stamp = pd.Timestamp("2012-03-11 1:30", tz="US/Eastern")

# %%
stamp
# Out:
# Timestamp('2012-03-11 01:30:00-0500', tz='US/Eastern')

# %%
dates = pd.date_range("2012-03-07 09:30", periods = 10, freq = "B")

# %%
ts
# Out:
# 2012-03-09 09:30:00    0.105947
# 2012-03-10 09:30:00    0.571502
# 2012-03-11 09:30:00    0.236482
# 2012-03-12 09:30:00   -0.749915
# 2012-03-13 09:30:00   -0.432236
# 2012-03-14 09:30:00   -2.384207
# Freq: D, dtype: float64

# %%
ts1 = ts[:7].tz_localize("Europe/London")

# %%
ts2 = ts1[2:].tz_convert("Europe/Moscow")

# %%
result = ts1 + ts2

# %%
result.index
# Out:
# DatetimeIndex(['2012-03-09 09:30:00+00:00', '2012-03-10 09:30:00+00:00',
#                '2012-03-11 09:30:00+00:00', '2012-03-12 09:30:00+00:00',
#                '2012-03-13 09:30:00+00:00', '2012-03-14 09:30:00+00:00'],
#               dtype='datetime64[us, UTC]', freq=None)
