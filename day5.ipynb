# %%
import numpy as np

# %%
import pandas as pd

# %%
ser = pd.Series(np.arange(3.))

# %%
ser
# Out:
# 0    0.0
# 1    1.0
# 2    2.0
# dtype: float64

# %%
ser.iloc[-1]
# Out:
# np.float64(2.0)

# %%
ser2 = pd.Series(np.arange(3.), index = ["a", "b", "c"])

# %%
ser2.iloc[-1]
# Out:
# np.float64(2.0)

# %%
ser[:2]
# Out:
# 0    0.0
# 1    1.0
# dtype: float64

# %%
data = pd.DataFrame(np.arange(16).reshape((4,4)), index = ["ohio", "colorade", "utah", "new york"], columns = ["one", "two", "three", "four"])

# %%
data
# Out:
#           one  two  three  four
# ohio        0    1      2     3
# colorade    4    5      6     7
# utah        8    9     10    11
# new york   12   13     14    15

# %%
data.loc[:, "one"] = 1

# %%
data
# Out:
#           one  two  three  four
# ohio        1    1      2     3
# colorade    1    5      6     7
# utah        1    9     10    11
# new york    1   13     14    15

# %%
data.iloc[2] = 5

# %%
data
# Out:
#           one  two  three  four
# ohio        1    1      2     3
# colorade    1    5      6     7
# utah        5    5      5     5
# new york    1   13     14    15

# %%
data.loc[data["four"] > 5] = 3

# %%
data
# Out:
#           one  two  three  four
# ohio        1    1      2     3
# colorade    3    3      3     3
# utah        5    5      5     5
# new york    3    3      3     3

# %%
data.loc[data.three == 5, "three"] = 6

# %%
data
# Out:
#           one  two  three  four
# ohio        1    1      2     3
# colorade    3    3      3     3
# utah        5    5      6     5
# new york    3    3      3     3

# %%
s1 = pd.Series([7.3, -2.5, 3.4, 1.5], index = ["a", "c", "d", "e"])

# %%
s2 = pd.Series([-2.1, 3.6, -1.5, 4, 3.1], index = ["a", "c", "e", "f", "g"])

# %%
s1 + s2
# Out:
# a    5.2
# c    1.1
# d    NaN
# e    0.0
# f    NaN
# g    NaN
# dtype: float64

# %%
df1 = pd.DataFrame(np.arange(9.).reshape((3,3)), columns = list("bcd"), index = ["ohio", "texas", "colorado"])

# %%
df2 = pd.DataFrame(np.arange(12.).reshape((4,3)), columns = list("bde"), index = ["utah", "ohio", "texas", "oregon"])

# %%
df1 + df2
# Out:
#             b   c     d   e
# colorado  NaN NaN   NaN NaN
# ohio      3.0 NaN   6.0 NaN
# oregon    NaN NaN   NaN NaN
# texas     9.0 NaN  12.0 NaN
# utah      NaN NaN   NaN NaN

# %%
df1 = pd.DataFrame({"A":[1,2]})

# %%
df2 = pd.DataFrame({"B":[3,4]})

# %%
df1
# Out:
#    A
# 0  1
# 1  2

# %%
df2
# Out:
#    B
# 0  3
# 1  4

# %%
df1 + df2
# Out:
#     A   B
# 0 NaN NaN
# 1 NaN NaN
