# %%
import numpy as np

# %%
import pandas as pd

# %%
float_data = pd.Series([1.2, -3.5, np.nan, 0])

# %%
float_data
# Out:
# 0    1.2
# 1   -3.5
# 2    NaN
# 3    0.0
# dtype: float64

# %%
float_data.isna()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
string_data = pd.Series(["aardvark", np.nan, None, "avocado"])

# %%
string_data
# Out:
# 0    aardvark
# 1         NaN
# 2         NaN
# 3     avocado
# dtype: str

# %%
string_data.isna()
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# dtype: bool

# %%
float_data = pd.Series([1, 2, None], dtype = "float64")

# %%
float_data
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
float_data.isna()
# Out:
# 0    False
# 1    False
# 2     True
# dtype: bool

# %%
data = pd.Series([1, np.nan, 3.5, np.nan, 7])

# %%
data.dropna()
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data[data.notna()]
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data = pd.DataFrame([[1.,6.5,3.],[1.,np.nan,np.nan],[np.nan, np.nan, np.nan], [np.nan, 6.5, 3.]])

# %%
data
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
data.dropna()
# Out:
#      0    1    2
# 0  1.0  6.5  3.0

# %%
data.dropna(how = "all")
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 3  NaN  6.5  3.0

# %%
data[4] = np.nan

# %%
data
# Out:
#      0    1    2   4
# 0  1.0  6.5  3.0 NaN
# 1  1.0  NaN  NaN NaN
# 2  NaN  NaN  NaN NaN
# 3  NaN  6.5  3.0 NaN

# %%
data.dropna(axis = "columns", how = "all")
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
df = pd.DataFrame(np.random.standard_normal((7,3)))

# %%
df.iloc[:4, 1] = np.nan

# %%
df.iloc[:2,2] = np.nan

# %%
df
# Out:
#           0         1         2
# 0  1.215051       NaN       NaN
# 1  0.237118       NaN       NaN
# 2  1.030821       NaN  0.836778
# 3 -0.717970       NaN  1.616526
# 4 -0.341939  0.164093 -0.542329
# 5 -0.809263 -0.571872 -1.295749
# 6  1.697541 -0.728149 -0.671134

# %%
df.dropna()
# Out:
#           0         1         2
# 4 -0.341939  0.164093 -0.542329
# 5 -0.809263 -0.571872 -1.295749
# 6  1.697541 -0.728149 -0.671134

# %%
df.dropna(thresh = 2)
# Out:
#           0         1         2
# 2  1.030821       NaN  0.836778
# 3 -0.717970       NaN  1.616526
# 4 -0.341939  0.164093 -0.542329
# 5 -0.809263 -0.571872 -1.295749
# 6  1.697541 -0.728149 -0.671134
